# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# The main data
train_data = pd.read_csv('/home/long/Downloads/train.csv')
test_data = pd.read_csv('/home/long/Downloads/test.csv')
# merge 2 data (all data of train and test)
all_data = pd.concat([train, test])
# all_data.head()

# %%
# create figure 
fig= plt.subplots(figsize=(16, 12))
try:
    # Create location for Top cat names     
    plt.subplot(1, 2, 1)
    text_cat = ' '.join(all_data.loc[all_data['Type'] == 2, 'Name'].fillna('').values)
    
    if not text_cat:
        raise ValueError("No text data found for cats.")   
        
    wordcloud = WordCloud(max_font_size=None, background_color='white',
                          width=1200, height=1000).generate(text_cat)
    plt.imshow(wordcloud)
    plt.title('Top cat names')
    plt.axis("off")
    
    # Create location for Top dog names     
    plt.subplot(1, 2, 2)
    text_dog = ' '.join(all_data.loc[all_data['Type'] == 1, 'Name'].fillna('').values)
    
    if not text_dog:
        raise ValueError("No text data found for dogs.")
    
    wordcloud = WordCloud(max_font_size=None, background_color='white',
                          width=1200, height=1000).generate(text_dog)
    plt.imshow(wordcloud)
    plt.title('Top dog names')
    plt.axis("off")
    
    plt.show()
    
    
    
except ValueError as e:
    print("ValueError: ", e)
# Out:
# /tmp/ipykernel_3223/2359574130.py:5: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1, 2, 1)

# %% [markdown]
# # What are the most commonly given names for dogs and cats?

# %% [raw]
# -> Cat: Kitten
# -> Dog: Puppies
